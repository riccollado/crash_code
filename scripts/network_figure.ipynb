# %%
from gen_manager.network import generate_network

# %%
num_nodes = 55
num_layers = 4
density = 0.35
network_graph, figure, pos = generate_network(
    num_nodes,
    num_layers,
    density,
)

# %%
# Later we write the file to disk with:
temporarylocation = "output/testout.pdf"

with open(temporarylocation, "wb") as out:
    out.write(figure)
    out.close()
