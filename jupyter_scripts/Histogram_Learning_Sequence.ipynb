R=np.array(R)
R_1=np.array(R_1)
ML = np.array(ML)

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(R, 20, normed=1,  alpha=0.5)
plt.title("Random Sampling")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

plt.axvline(np.mean(R), color='k', linestyle='solid',
            linewidth=1, label='mean: ${:,}'.format(int(np.mean(R))*100000))
plt.axvline(np.median(R), color='k', linestyle='dashed',
            linewidth=1, label='median: ${:,}'.format(int(np.median(R))*100000))
plt.axvline(np.mean(R)-np.std(R), color='r', linestyle='solid',
            linewidth=1, label='std: ${:,}'.format(int(np.std(R))*100000))
plt.axvline(np.mean(R)+np.std(R), color='r', linestyle='solid', linewidth=1)

plt.legend()
plt.savefig('R.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(R_1, 20, normed=1,  alpha=0.5)
plt.title("Directed Random Sampling")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

plt.axvline(np.mean(R_1), color='k', linestyle='solid',
            linewidth=1, label='mean: ${:,}'.format(int(np.mean(R_1))*100000))
plt.axvline(np.median(R_1), color='k', linestyle='dashed',
            linewidth=1, label='median: ${:,}'.format(int(np.median(R_1))*100000))
plt.axvline(np.mean(R_1)-np.std(R_1), color='r', linestyle='solid',
            linewidth=1, label='std: ${:,}'.format(int(np.std(R_1))*100000))
plt.axvline(np.mean(R_1)+np.std(R_1), color='r', linestyle='solid', linewidth=1)

plt.legend()
plt.savefig('R_1.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(ML, 20, normed=1,  alpha=0.5)
plt.title("ML - Approach")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

plt.axvline(np.mean(ML), color='k', linestyle='solid',
            linewidth=1, label='mean: ${:,}'.format(int(np.mean(ML))*100000))
plt.axvline(np.median(ML), color='k', linestyle='dashed',
            linewidth=1, label='median: ${:,}'.format(int(np.median(ML))*100000))
plt.axvline(np.mean(ML)-np.std(ML), color='r', linestyle='solid',
            linewidth=1, label='std: ${:,}'.format(int(np.std(ML))*100000))
plt.axvline(np.mean(ML)+np.std(ML), color='r', linestyle='solid', linewidth=1)
plt.legend()

plt.savefig('ML.png')
plt.show()

import matplotlib as mpl
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(R, 20, normed=1,  alpha=0.5)
plt.title("Random Sampling")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

# plt.axvline(np.mean(R), color='k', linestyle='solid',
#             linewidth=1, label='mean: ${:,}'.format(int(np.mean(R))*100000))
# plt.axvline(np.median(R), color='k', linestyle='dashed',
#             linewidth=1, label='median: ${:,}'.format(int(np.median(R))*100000))
# plt.axvline(np.mean(R)-np.std(R), color='r', linestyle='solid',
#             linewidth=1, label='std: ${:,}'.format(int(np.std(R))*100000))
# plt.axvline(np.mean(R)+np.std(R), color='r', linestyle='solid', linewidth=1)

# plt.legend()
plt.savefig('R_simple.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(R_1, 20, normed=1,  alpha=0.5)
plt.title("Directed Random Sampling")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

# plt.axvline(np.mean(R_1), color='k', linestyle='solid',
#             linewidth=1, label='mean: ${:,}'.format(int(np.mean(R_1))*100000))
# plt.axvline(np.median(R_1), color='k', linestyle='dashed',
#             linewidth=1, label='median: ${:,}'.format(int(np.median(R_1))*100000))
# plt.axvline(np.mean(R_1)-np.std(R_1), color='r', linestyle='solid',
#             linewidth=1, label='std: ${:,}'.format(int(np.std(R_1))*100000))
# plt.axvline(np.mean(R_1)+np.std(R_1), color='r', linestyle='solid', linewidth=1)

# plt.legend()
plt.savefig('R_1_simple.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1)

# plt.figure(figsize=(height_in_inches, width_in_inches), dpi=dots_per_inch)
plt.hist(ML, 20, normed=1,  alpha=0.5)
plt.title("ML - Approach")
plt.xlabel('cost in $100,000')
plt.ylabel('probability')

formatter = ticker.FormatStrFormatter('%1.3f')
ax.yaxis.set_major_formatter(formatter)
plt.xlim(450, 3000)

# plt.axvline(np.mean(ML), color='k', linestyle='solid',
#             linewidth=1, label='mean: ${:,}'.format(int(np.mean(ML))*100000))
# plt.axvline(np.median(ML), color='k', linestyle='dashed',
#             linewidth=1, label='median: ${:,}'.format(int(np.median(ML))*100000))
# plt.axvline(np.mean(ML)-np.std(ML), color='r', linestyle='solid',
#             linewidth=1, label='std: ${:,}'.format(int(np.std(ML))*100000))
# plt.axvline(np.mean(ML)+np.std(ML), color='r', linestyle='solid', linewidth=1)

# plt.legend()
plt.savefig('ML_simple.png')
plt.show()

import matplotlib as mpl
ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))

# %%
#Savings:
(np.median(R)- np.median(ML))*100000
# Out:
# 23124786.677359316

# %%
#Reduced risk:
(np.std(R)- np.std(ML))/np.std(R)
# Out:
# 0.5845589424625077
