# %%
import io
import os

from generator_network import generate_network

#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt

import networkx as nx

# %%
num_nodes = 25
num_layers = 8
density = 0.20
G, figure, pos = generate_network(num_nodes, num_layers, density)

# %%
#Later we write the file to disk with:
temporarylocation="testout.pdf"

with open(temporarylocation,'wb') as out:
    out.write(figure)
    out.close()
